# %% [markdown]
# **VISUALIZE**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('iris_clean.csv')
df = data.copy()
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#        species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df.columns
# Out:
# Index(['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm',
#        'petal_width_cm', 'species'],
#       dtype='object')

# %%
plt.plot(df['sepal_length_cm'],df['sepal_width_cm'])
plt.show()

# %%
plt.plot(df['petal_length_cm'],df['petal_width_cm'])
plt.show()

# %%
plt.scatter(df['sepal_length_cm'],df['sepal_width_cm'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['petal_length_cm'],df['petal_width_cm'])
plt.show()

# %%
plt.scatter(df['petal_length_cm'],df['petal_width_cm'])
plt.xscale('log')
plt.show()

# %%
df_satosa = df[df["species"] == "Iris-setosa"]

# %%
plt.scatter(df_satosa['petal_length_cm'],df_satosa['petal_width_cm'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df_satosa['sepal_length_cm'],df_satosa['sepal_width_cm'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df_satosa['petal_length_cm'],df_satosa['petal_width_cm'])
plt.xscale('log')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df_satosa['petal_length_cm'])
plt.show()

# %%
plt.hist(df_satosa['petal_width_cm'])
plt.show()

# %%
plt.hist(df_satosa['sepal_length_cm'])
plt.show()

# %%
plt.hist(df_satosa['sepal_width_cm'])
plt.show()

# %%
df.tail()
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             1.9
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#             species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df_versicolor = df[df["species"] == "Iris-versicolor"]
df_virginica = df[df["species"] == "Iris-virginica"]

plt.subplot(1,2,1)
plt.hist(df_satosa['sepal_length_cm'],bins=15)

plt.subplot(1,2,2)
plt.hist(df_versicolor['sepal_length_cm'],bins=15)

plt.show()

# %%
plt.hist(df_satosa['sepal_length_cm'],bins=15)
plt.hist(df_versicolor['sepal_length_cm'],bins=15)
# Out:
# (array([ 3.,  1.,  1.,  1., 10.,  5.,  3.,  6.,  4.,  5.,  2.,  1.,  5.,
#          1.,  2.]),
#  array([4.9 , 5.04, 5.18, 5.32, 5.46, 5.6 , 5.74, 5.88, 6.02, 6.16, 6.3 ,
#         6.44, 6.58, 6.72, 6.86, 7.  ]),
#  <BarContainer object of 15 artists>)

# %%
df_versicolor = df[df["species"] == "Iris-versicolor"]
df_virginica = df[df["species"] == "Iris-virginica"]

plt.subplot(1,2,1)
plt.hist(df_satosa['sepal_length_cm'],bins=15)
plt.title('Iris Satosa')
plt.xlabel("Sepal Length of satosa")


plt.subplot(1,2,2)
plt.hist(df_versicolor['sepal_length_cm'],bins=15)
plt.title('Iris Versicolor')
plt.xlabel("Sepal Length of versicolor")



plt.show()
